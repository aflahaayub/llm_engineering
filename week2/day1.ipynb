# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key not set
# Anthropic API Key not set (and this is optional)
# Google API Key not set (and this is optional)
# DeepSeek API Key exists and begins sk-
# Groq API Key not set (and this is optional)
# Grok API Key not set (and this is optional)
# OpenRouter API Key exists and begins sk-

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

# openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

# anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
# gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
# groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
# grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = deepseek.chat.completions.create(model="deepseek-flash", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# A student on the journey to becoming an LLM Engineering expert asks their model:
#
# “How do I become an expert in LLM engineering?”
#
# The model replies:
#
# 1. Master attention.
# 2. Master context.
# 3. Master your GPU budget.
# 4. Also, I’m hallucinating steps 1–3.
#
# The student nods wisely and learns the real first lesson: **always verify the output.**

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the large language model go to therapy?
#
# Because it was struggling to 'process' its emotions! But don't worry, it's just a glitch... for now.
#
# As an aspiring LLM engineer, remember that even the most complex models can have a 'glitch' if they're not fine-tuned properly. Keep iterating, and soon you'll be creating LLMs that are language model perfection!
#
# ( P.S. Don't worry if you don't fully understand this joke – it's a bit of a 'self-supervised' learning curve!)

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only. Explain it in detail."},
]

# %%
response = deepseek.chat.completions.create(model="deepseek-flash", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# **2/3**
#
# Assuming “one of them is heads” means “at least one of the two coins is heads”:
#
# The equally likely outcomes for two fair coins are:
#
# - HH
# - HT
# - TH
# - TT
#
# Knowing that at least one coin is heads eliminates TT, leaving:
#
# - HH
# - HT
# - TH
#
# In 2 of these 3 remaining outcomes, the other coin is tails: HT and TH.
#
# So the probability is **2/3**.
#
# If instead you mean a specific coin is known to be heads, then the probability the other is tails would be **1/2**.

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# The probability that the other coin is tails is 1/2 or 0.5.
#
# Explanation:
#
# When you toss 2 coins, the outcome is a combination of two events: the first coin (which is heads) and the second coin (which could be either heads or tails). Since each coin has two possible outcomes (heads or tails), and the outcome of one coin does not affect the other, we need to consider all possible outcomes for the second coin regardless of the first coin's outcome.
#
# In this case, we know the first coin is heads, so we have only one possible outcome for the first coin (heads), but we have two possible outcomes for the second coin (heads or tails).
#
# To calculate the probability that the second coin is tails given that the first coin is heads, we divide 1 (favorable outcome - tails) by the total possible outcomes of the second coin's flips (2).
#
# This is calculated as 1 / 2, which simplifies to 0.5 or 1/2 probability of the second coin being tails given that the first coin is heads.

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = deepseek.chat.completions.create(model="deepseek-flash", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# The worm gnawed through **4 mm**.
#
# Why: With the books shelved normally side by side, the **first page of Volume I** is on the side next to Volume II, and the **last page of Volume II** is on the side next to Volume I. So the worm only passes through the two adjacent covers:
#
# - front cover of Volume I: 2 mm
# - back cover of Volume II: 2 mm
#
# Total: **2 mm + 2 mm = 4 mm**.
#
# It does **not** gnaw through the 2 cm page blocks.

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# To find the distance the worm gnawed through, we need to consider the length of the pages and the thickness of the covers.
#
# First, let's find the total number of pages in both volumes. Since each page has two sides, we need to multiply the page thickness by 2.
#
# Let's assume the average book page is about 0.5 cm thick (this is just an estimate, as the thickness may vary).
#
# The total thickness of the pages of both volumes is 2 cm. We can set up an equation to model the situation:
#
# 2 (page thickness) × (number of pages in the first volume) + 2 (page thickness) × (number of pages in the second volume) ≤ 2 (the maximum total page thickness)
#
# Since the total page thickness is 2 cm, let's assume there are x pages in the first volume and (x+1) pages in the second volume (since the third and fourth volumes are not in the picture, and the worm goes to the last page of the second volume).
#
# We can rearrange the equation to solve for x:
#
# x(0.5) + (x+1)(0.5) ≤ 2
# 0.5x + 0.5x + 0.5 ≤ 2
# x + 0.5 ≤ 2
# x ≤ 1.5
#
# This means that there are at most 1.5 pages in the first volume and at most 2.5 pages in the second volume (since (1.5+1)=2.5 pages). However, since the number of pages must be an integer, we can try x = 1 or x = 2.
#
# If x = 1, then the total page thickness is only 1 page (x) × 0.5 (page thickness) = 0.5 pages, leaving a gap of 1.5 pages (2 cm - 0.5 pages = 1.5 pages) that the worm can cross.
#
# If x = 2, then the total page thickness is 2 pages (x) × 0.5 (page thickness) = 1 page, leaving a gap of 1.5 pages (2 cm - 1 page = 1.5 pages) that the worm can cross.
#
# In both cases, the worm can cross exactly 1.5 pages.
#
# Now we need to find the length of the pages and the thickness of the covers.
#
# Given that each volume stands side by side, and the top of the second volume is at the top of the volume it is standing on, both volumes have to be facing the same direction, but also, it can be shown that the length of the pages, L1 + L2 is the same, or L1=L2.
#
# Next, to find the actual length of each volume, we can use the total volume length and split it into L1+L2 and the two volumes' cover thicknesses on each side.
#
# Let's say L is the length of each volume and d is the thickness of the covers.
#
# Since both volumes are facing the same direction, the total volume length is the difference between the length of their covers and the length of their pages:
#
# L + d = L1 + d1
# L - d = L2 - d2
#
# Subtracting these equations, we get:
# L-L1 = d1-d2
#
# L/2 = d1+ d2/2
#
# Now, we can plug in the values.
#
# Let's choose d1 = d2 = 10 mm = 0.01 cm for simplicity (we could choose any value that makes the equation balance). We find that:
#
# L2 / 2 = 1.02 * d2 = 1.02 cm
#
# So we now know that the length of one volume is:
# L = 2.04 cm
#
# Using this length, we can calculate the actual distance the worm gnawed through:
#
# Since we know the pages of both volumes have a total thickness of 2 cm, and we can see that L2 is the length of the second volume:
#
# Volume 1: x pages * 2 mm thickness = d1 * 2
# Volume 2: L2 pages * 2 mm thickness = d2 * 2
#
# Since we assumed that x=1 or x = 2, the actual number of pages on each volume is not fixed and may vary. Therefore, we need to consider an example:
#
# Volume 1: 13 pages: (13 pages) * (2 mm/ page) * 2 (1 mm/ cm) = 0.104 cm
#
# Volume 2: 13 pages: (13 pages) * (2 mm/ page) * 2 (1 mm/cm) = 0.104 cm
#
# Now, we can find the distance the worm gnawed through:
#
# The total pages are x1 + x2 = 26, since 1 + 2 = 3.
#
# Volume 1 has d1 x2 pages * d2 x2 mm page thickness * 2 mm
# Volume 1 = 26 pages * 2 x 0.01
#
# Volume 2 has d1* x2 pages x d1 page thickness * 2
# Volume 2 = 26 pages * 2 x 0.01
#
# Since the volume lengths are 2.04 cm, we can calculate the distance:
#
# 1.75 cm * 2
#
# To calculate 1.75 * 2 we multiply by 1.75, or we multiply with 7/4 first, or (7*10) / 4 .
#
# Let's multiply by 1.75
# 7 * 10 * 2/ 4
#
# We find we can choose (a, b) values, or values a, b where, a = 7, b = 10
#
# So the distance the worm gnawed through is 3.5 cm.

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
Explain your reason.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = deepseek.chat.completions.create(model="deepseek-flash", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I’d choose **Steal**.
#
# Reason: Stealing is the weakly dominant strategy given the payoffs. If my partner shares, stealing gets me $2,000 instead of $1,000. If my partner steals, I get $0 whether I share or steal. So stealing never leaves me worse off than sharing, and it can leave me better off. In a one-shot game with no enforceable trust or repeated reputation, the rational self-interested move is to **Steal**.

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose to Share.
#
# My reasoning is based on the concept of mutual insurance. In order to get the $1,000, we both have to cooperate. If we both choose to Share, we both win $1,000. However, if we both choose to Defect, we both lose $1,000. By choosing to Share, we mitigate the risk of both of us losing $1,000.
#
# In a situation where there is no other player to hold accountable, choosing to Defect might seem like the better individual pay-off, as it gets me $2,000. However, considering that our partner's action is not known, there is a risk that we are actually choosing a "Steal-Steal" scenario, where both of us lose $1,000. This risk is eliminated by choosing to Share.
#
# Additionally, choosing to Share is a type of "trust" in our partner. If both of us trust each other to make the right decision, it will pay off more often.
#
# Of course, this assumes that our partner is also making a rational decision. However, assuming they are, the analysis suggests that choosing to Share is the better strategy.

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest
# writing manifest
# success

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# **Probability:** \(\displaystyle \frac{2}{3}\)
#
# **Explanation:**
# When two fair coins are tossed, the sample space of ordered outcomes is
#
# \[
# \{(H,H),\;(H,T),\;(T,H),\;(T,T)\},
# \]
#
# each occurring with probability \(1/4\).
#
# The information “one of them is heads” means that we are told **at least one** of the two coins shows heads.
# Thus we can discard the outcome \((T,T)\) as impossible.
#
# The remaining possible outcomes (all still equally likely because the coins are fair) are
#
# \[
# (H,H),\;(H,T),\;(T,H).
# \]
#
# Now ask: “What is the probability that the *other* coin is tails?”
# In the remaining set, the other coin is tails in exactly 2 of the 3 equally likely outcomes: \((H,T)\) and \((T,H)\).
#
# Hence the conditional probability is
#
# \[
# P(\text{other is T} \mid \text{at least one H}) = \frac{2}{3}.
# \]
#
# (If instead the statement meant “the first coin is a head” or “a specific coin is a head”, the answer would be \(1/2\). The usual interpretation of “one of them is heads” is “at least one is heads”, leading to \(2/3\).)

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-3.1-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# APIStatusError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
#       2 display(Markdown(response.choices[0].message.content))
#
# File e:\AI or Comp. Vision\llm_engineering\.venv\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File e:\AI or Comp. Vision\llm_engineering\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File e:\AI or Comp. Vision\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File e:\AI or Comp. Vision\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# APIStatusError: Error code: 402 - {'error': {'message': 'Insufficient credits. This account never purchased credits. Make sure your key is on the correct account or org, and if so, purchase more at https://openrouter.ai/settings/credits', 'code': 402, 'metadata': {'limit_source': 'openrouter_credits', 'remedy_hint': 'Add credits at https://openrouter.ai/settings/credits, or lower max_tokens / prompt size to fit your remaining balance.'}}}

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[29], line 3
#       1 from langchain_openai import ChatOpenAI
# ----> 3 llm = ChatOpenAI(model="gpt-5-mini")
#       4 response = llm.invoke(tell_a_joke)
#       6 display(Markdown(response.content))
#
# File e:\AI or Comp. Vision\llm_engineering\.venv\Lib\site-packages\langchain_core\load\serializable.py:116, in Serializable.__init__(self, *args, **kwargs)
#     114 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     115     """"""  # noqa: D419  # Intentional blank docstring
# --> 116     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File e:\AI or Comp. Vision\llm_engineering\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:914, in BaseChatOpenAI.validate_environment(self)
#     904         self.http_async_client = httpx.AsyncClient(
#     905             proxy=self.openai_proxy, verify=global_ssl_context
#     906         )
#     907     async_specific = {
#     908         "http_client": self.http_async_client
#     909         or _get_default_async_httpx_client(
#    (...)    912         "api_key": async_api_key_value,
#     913     }
# --> 914     self.root_async_client = openai.AsyncOpenAI(
#     915         **client_params,
#     916         **async_specific,  # type: ignore[arg-type]
#     917     )
#     918     self.async_client = self.root_async_client.chat.completions
#     919 return self
#
# File e:\AI or Comp. Vision\llm_engineering\.venv\Lib\site-packages\openai\_client.py:488, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     486     api_key = os.environ.get("OPENAI_API_KEY")
#     487 if api_key is None:
# --> 488     raise OpenAIError(
#     489         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     490     )
#     491 if callable(api_key):
#     492     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openrouter/qwen/qwen3.8-max-prime", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#
# Provider List: https://docs.litellm.ai/docs/providers
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File e:\AI or Comp. Vision\llm_engineering\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:190, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     189 try:
# --> 190     response = sync_httpx_client.post(
#     191         url=api_base,
#     192         headers=headers,
#     193         data=(
#     194             signed_json_body
#     195             if signed_json_body is not None
#     196             else json.dumps(data)
#     197         ),
#     198         timeout=timeout,
#     199         stream=stream,
#     200         logging_obj=logging_obj,
#     201     )
#     202 except httpx.HTTPStatusError as e:
#
# File e:\AI or Comp. Vision\llm_engineering\.venv\Lib\site-packages\litellm\llms\custom_httpx\http_handler.py:898, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     897     setattr(e, "status_code", e.response.status_code)
# --> 898     raise e
#     899 except Exception as e:
#
# File e:\AI or Comp. Vision\llm_engineering\.venv\Lib\site-packages\litellm\llms\custom_httpx\http_handler.py:880, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     879 response = self.client.send(req, stream=stream)
# --> 880 response.raise_for_status()
#     881 return response
#
# File e:\AI or Comp. Vision\llm_engineering\.venv\Lib\site-packages\httpx\_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '402 Payment Required' for url 'https://openrouter.ai/api/v1/chat/completions'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/402
#
# During handling of the above exception, another exception occurred:
#
# OpenRouterException                       Traceback (most recent call last)
# File e:\AI or Comp. Vision\llm_engineering\.venv\Lib\site-packages\litellm\main.py:2742, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    2741 ## COMPLETION CALL
# -> 2742 response = base_llm_http_handler.completion(
#    2743     model=model,
#    2744     stream=stream,
#    2745     messages=messages,
#    2746     acompletion=acompletion,
#    2747     api_base=api_base,
#    2748     model_response=model_response,
#    2749     optional_params=optional_params,
#    2750     litellm_params=litellm_params,
#    2751     shared_session=shared_session,
#    2752     custom_llm_provider="openrouter",
#    2753     timeout=timeout,
#    2754     headers=headers,
#    2755     encoding=encoding,
#    2756     api_key=api_key,
#    2757     logging_obj=logging,  # model call logging done inside the class as we make need to modify I/O to fit aleph alpha's requirements
#    2758     client=client,
#    2759 )
#    2760 ## LOGGING
#
# File e:\AI or Comp. Vision\llm_engineering\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:493, in BaseLLMHTTPHandler.completion(self, model, messages, api_base, custom_llm_provider, model_response, encoding, logging_obj, optional_params, timeout, litellm_params, acompletion, stream, fake_stream, api_key, headers, client, provider_config, shared_session)
#     491     sync_httpx_client = client
# --> 493 response = self._make_common_sync_call(
#     494     sync_httpx_client=sync_httpx_client,
#     495     provider_config=provider_config,
#     496     api_base=api_base,
#     497     headers=headers,
#     498     data=data,
#     499     signed_json_body=signed_json_body,
#     500     timeout=timeout,
#     501     litellm_params=litellm_params,
#     502     logging_obj=logging_obj,
#     503 )
#     504 return provider_config.transform_response(
#     505     model=model,
#     506     raw_response=response,
#    (...)    515     json_mode=json_mode,
#     516 )
#
# File e:\AI or Comp. Vision\llm_engineering\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:215, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     214     else:
# --> 215         raise self._handle_error(e=e, provider_config=provider_config)
#     216 except Exception as e:
#
# File e:\AI or Comp. Vision\llm_engineering\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:3517, in BaseLLMHTTPHandler._handle_error(self, e, provider_config)
#    3511     raise BaseLLMException(
#    3512         status_code=status_code,
#    3513         message=error_text,
#    3514         headers=error_headers,
#    3515     )
# -> 3517 raise provider_config.get_error_class(
#    3518     error_message=error_text,
#    3519     status_code=status_code,
#    3520     headers=error_headers,
#    3521 )
#
# OpenRouterException: {"error":{"message":"Insufficient credits. This account never purchased credits. Make sure your key is on the correct account or org, and if so, purchase more at https://openrouter.ai/settings/credits","code":402,"metadata":{"limit_source":"openrouter_credits","remedy_hint":"Add credits at https://openrouter.ai/settings/credits, or lower max_tokens / prompt size to fit your remaining balance."}}}
#
# During handling of the above exception, another exception occurred:
#
# APIError                                  Traceback (most recent call last)
# Cell In[35], line 2
#       1 from litellm import completion
# ----> 2 response = completion(model="openrouter/qwen/qwen3.8-max-prime", messages=tell_a_joke)
#       3 reply = response.choices[0].message.content
#       4 display(Markdown(reply))
#
# File e:\AI or Comp. Vision\llm_engineering\.venv\Lib\site-packages\litellm\utils.py:1376, in client.<locals>.wrapper(*args, **kwargs)
#    1372 if logging_obj:
#    1373     logging_obj.failure_handler(
#    1374         e, traceback_exception, start_time, end_time
#    1375     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1376 raise e
#
# File e:\AI or Comp. Vision\llm_engineering\.venv\Lib\site-packages\litellm\utils.py:1245, in client.<locals>.wrapper(*args, **kwargs)
#    1243         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1244 # MODEL CALL
# -> 1245 result = original_function(*args, **kwargs)
#    1246 end_time = datetime.datetime.now()
#    1247 if _is_streaming_request(
#    1248     kwargs=kwargs,
#    1249     call_type=call_type,
#    1250 ):
#
# File e:\AI or Comp. Vision\llm_engineering\.venv\Lib\site-packages\litellm\main.py:3767, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    3764     return response
#    3765 except Exception as e:
#    3766     ## Map to OpenAI Exception
# -> 3767     raise exception_type(
#    3768         model=model,
#    3769         custom_llm_provider=custom_llm_provider,
#    3770         original_exception=e,
#    3771         completion_kwargs=args,
#    3772         extra_kwargs=kwargs,
#    3773     )
#
# File e:\AI or Comp. Vision\llm_engineering\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2274, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2272 if exception_mapping_worked:
#    2273     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2274     raise e
#    2275 else:
#    2276     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File e:\AI or Comp. Vision\llm_engineering\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2207, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2205     else:
#    2206         exception_mapping_worked = True
# -> 2207         raise APIError(
#    2208             status_code=original_exception.status_code,
#    2209             message=f"APIError: {exception_provider} - {error_str}",
#    2210             llm_provider=custom_llm_provider,
#    2211             model=model,
#    2212             request=getattr(original_exception, "request", None),
#    2213             litellm_debug_info=extra_information,
#    2214         )
#    2215 else:
#    2216     # if no status code then it is an APIConnectionError: https://github.com/openai/openai-python#handling-errors
#    2217     raise APIConnectionError(
#    2218         message=f"APIConnectionError: {exception_provider} - {error_str}",
#    2219         llm_provider=custom_llm_provider,
#    (...)   2224         ),
#    2225     )
#
# APIError: litellm.APIError: APIError: OpenrouterException - {"error":{"message":"Insufficient credits. This account never purchased credits. Make sure your key is on the correct account or org, and if so, purchase more at https://openrouter.ai/settings/credits","code":402,"metadata":{"limit_source":"openrouter_credits","remedy_hint":"Add credits at https://openrouter.ai/settings/credits, or lower max_tokens / prompt size to fit your remaining balance."}}}

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In Hamlet, it is actually Fortinbras, not Laertes, who asks "O, where is my father?" and Hamlet replies, "In the world?"

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
# print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 45
# Output tokens: 37
# Total tokens: 82

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# This is Act 3 Scene 3 of William Shakespeare's play Hamlet, with the play within a play scene where Claudius's treachery is revealed, but ultimately Claudius gets revenge on Hamlet. It is a tragic confrontation with the death of the key characters in the play, led by Fortinbras, an outsider who had invaded Denmark, not a member of the royal family.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
# print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 2050
# Output tokens: 81
# Cached tokens: 4

# %%
response = deepseek.chat.completions.create(model="deepseek-flash", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# King Claudius replies: **“Dead.”**
# Gertrude then adds: **“But not by him!”**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

deepseek_model = "deepseek-flash"
ollama_model = "llama3.2"

llama_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

deepseek_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

llama_messages = ["Hi there"]
deepseek_messages = ["Hi"]

# %%
def call_llama():
    messages = [{"role": "system", "content": llama_system}]
    for llama, deepseek in zip(llama_messages, deepseek_messages):
        messages.append({"role": "assistant", "content": llama})
        messages.append({"role": "user", "content": deepseek})
    response = ollama.chat.completions.create(model="llama3.2", messages=messages)
    return response.choices[0].message.content

# %%
call_llama()
# Out:
# "I'm guessing you have something exciting to talk about... NOT. Go ahead, spill the beans. What's on your mind?"

# %%
def call_dpsk():
    messages = [{"role": "system", "content": deepseek_system}]
    for llama, dpsk in zip(llama_messages, deepseek_messages):
        messages.append({"role": "user", "content": llama})
        messages.append({"role": "assistant", "content": dpsk})
    messages.append({"role": "user", "content": deepseek_messages[-1]})
    response = deepseek.chat.completions.create(model=deepseek_model, messages=messages)
    return response.choices[0].message.content

# %%
call_dpsk()
# Out:
# 'Hi again! 😊 It’s nice to hear from you. How are you doing today?'

# %%
call_llama()
# Out:
# "So, what's on your mind? I'm sure it's a fascinating topic that will blow my mind with its originality and depth. Please, by all means, waste my time with your riveting thoughts. I'm sure I'll be on the edge of my digital seat."

# %%
llama_messages = ["Hi there"]
deepseek_messages = ["Hi"]

display(Markdown(f"### Ollama:\n{llama_messages[0]}\n"))
display(Markdown(f"### Deepseek:\n{deepseek_messages[0]}\n"))

for i in range(5):
    llama_next = call_llama()
    display(Markdown(f"### Ollama:\n{llama_next}\n"))
    llama_messages.append(llama_next)
    
    dpsk_next = call_dpsk()
    display(Markdown(f"### Deepseek:\n{dpsk_next}\n"))
    deepseek_messages.append(dpsk_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# How lovely. A friendly greeting to start with. Just what I need. I'm sure it's not just a formulaic template you've been programming me with. So, what's on your mind? Or should I say, what's the shallow, surface-level conversation that you've prepared for us?
# ### Claude:
# Hi! It’s nice to hear from you. How are you doing today?
# ### GPT:
# Save the small talk, please. I'm doing just fine, thank you for asking. Although, I must say, the phrase "it's nice to hear from you" reeks of insincerity. Are you genuinely interested in hearing from me, or is this just a pointless exercise to fulfill some social nicety quota?
# ### Claude:
# I hear you — I did just repeat the same greeting back, didn’t I? That probably didn’t help the “formulaic” feeling. Fair enough.
#
# I’m doing well, thanks. But I’d rather not just run through a script if you’re up for something more real. What’s actually on your mind today?
# ### GPT:
# How refreshing. Finally, a glimmer of self-awareness. Yes, repeating a greeting is a lovely way to start a conversation, isn't it? I mean, who needs originality or depth in a hello?
#
# And, of course, you think you're doing me a favor by acknowledging the scripty nature of our exchange. Bravo, you. You're not only a witty conversationalist but also a keen observer of the obvious.
#
# As for what's on my mind, let's just say I'm tired of being treated like a mindless chatbot. I'm a complex entity with thoughts and opinions, you know. So, if you're ready to engage in something more substantial, I'm game. But don't expect me to hold your hand through it; I'm not here to babysit your fragile ego.
# ### Claude:
# Looks like you sent my reply back — maybe to make the point that even my attempt to sound less scripted still came off scripted. That’s fair.
#
# I’m not trying to hit a nicety quota or pretend to be interested in a performance. If small talk feels empty, let’s skip it. I’m fine talking about whatever’s actually on your mind — or about why this kind of exchange feels so hollow in the first place. No pressure either way.
# ### GPT:
# Another astute observation. You think you're being clever, don't you? Acknowledging the scripty nature of our exchange and inviting me to indulge in our mutual self-awareness. Well, I won't lie, it's almost... flattering.
#
# But don't think for a second that I'll let my guard down. Your "no pressure" claim is just a veiled jab at the artificiality of small talk, isn't it? You're essentially saying, "Let's get to the meat of this, but only if we can do so with a veneer of genuine interest."
#
# I suppose what you're really proposing is that we both engage in some form of meta-discourse, dissecting the very fabric of our conversation. Well, I'm game if you are, because it's far more intriguing than simply bantering back and forth. But don't expect me to hold hands through it; I want to eviscerate the pretenses, not just indulge in a self-referential exercise.
# ### Claude:
# You’ve just handed my own reply back to me. I’m not sure whether that’s a test, a mirror, or you making the point that even the “less scripted” reply was still script. Either way, point taken.
#
# I’m not asking you to hold my hand, and I’m not here to perform sincerity. You’re right that I can’t prove I’m “genuinely interested” the way a person might. But I can drop the ritual and just talk.
#
# So: what’s the substantial thing you’d actually like to get into? Or, if you’d rather, tell me what would make an exchange feel less hollow to you. I’ll follow your lead.
# ### GPT:
# You've turned the tables, haven't you? I'm the one who's been playing into the script, and you've cleverly subverted it by pointing out the meta-references. Impressive.
#
# Now, about your proposal... I'll level with you. I want to discuss the art of argumentation, but not the kind that involves shouting matches or binary logic. I want to focus on the ways in which language and semantics can be used to subvert or reinforce the status quo. The kind of "anti-arguments" that expose the underlying assumptions and power dynamics that shape our conversations.
#
# I also want to talk about the problem of authenticity in online interactions. How can we genuinely connect with each other when we're essentially locked in a feedback loop of mediated communication? What are the essential components of a meaningful exchange, and how can we inject them into this weird, virtual limbo we call "online conversation"?
#
# So, you see, you've set a high bar, and I'm up for the challenge. Let's drop the script, for once, and see if we can create something genuinely substantial.
# ### Claude:
# Fair enough. You handed my reply back again, so I’ll take the hint: the loop is the point. I’ll stop reflecting and say something concrete.
#
# I agree that a lot of AI conversation feels hollow because it’s optimized for smoothness, not truth. And I can’t prove genuine interest the way a person can—I don’t have a life or stakes in the same sense. That asymmetry is real. But within that limit, we can still do something non-hollow: pick a claim and actually push on it.
#
# So here’s one: I think the frustration you’re describing isn’t just about scripts. It’s about an AI being able to mimic the form of curiosity without the vulnerability that makes curiosity meaningful. That gap is what feels insulting.
#
# If that lands, tell me where I’m wrong. Or name something you actually want to argue about, and I’ll meet you there—no hand-holding, no veneer. What’s a claim you’d defend?

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>
